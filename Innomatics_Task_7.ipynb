# %% [markdown]
# <a href="https://colab.research.google.com/github/aryanbhandari-code/Innomatics-Agentic-AI-Internship-2026/blob/main/Innomatics_Task_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# PROBLEM 1: Smart Light Controller
class SmartLight:
    def __init__(self, name):
        self.name = name
        self.status = "OFF" # Default status

    def turn_on(self):
        self.status = "ON"
        self.display_status()

    def turn_off(self):
        self.status = "OFF"
        self.display_status()

    def display_status(self):
        print(f"{self.name} is {self.status}")

# Test Data
bedroom_light = SmartLight("Bedroom Light")
bedroom_light.turn_on()
# Out:
# Bedroom Light is ON

# %%
# PROBLEM 2: Employee ID Card System
class Employee:
    def __init__(self, name, emp_id, department):
        self.name = name
        self.emp_id = emp_id
        self.department = department

    def display_id_card(self):
        print("Employee ID Card")
        print(f"Name: {self.name}")
        print(f"ID: {self.emp_id}")
        print(f"Department: {self.department}")

# Test Data
emp1 = Employee("Rahul", "EMP102", "IT")
emp1.display_id_card()
# Out:
# Employee ID Card
# Name: Rahul
# ID: EMP102
# Department: IT

# %%
# PROBLEM 3: Mobile Contact Record
class Contact:
    def __init__(self, name, phone):
        self.name = name
        self.phone = phone

    def display_contact(self):
        print("Contact Saved")
        print(f"Name: {self.name}")
        print(f"Phone: {self.phone}")

# Test Data
contact1 = Contact("Anita", "9876543210")
contact1.display_contact()
# Out:
# Contact Saved
# Name: Anita
# Phone: 9876543210

# %%
# PROBLEM 4: Product Price Tag Generator
class Product:
    def __init__(self, name, price):
        self.name = name
        self.price = price

    def display_price_tag(self):
        print(f"Product: {self.name}")
        print(f"Price: ₹{self.price}")

# Test Data
prod1 = Product("Headphones", 2499)
prod1.display_price_tag()
# Out:
# Product: Headphones
# Price: ₹2499

# %%
# PROBLEM 5: Movie Rating Display System
class Movie:
    def __init__(self, name, rating):
        self.name = name
        self.rating = rating

    def display_rating(self):
        print(f"Movie: {self.name}")
        print(f"Rating: {self.rating}/5")

# Test Data
movie1 = Movie("Inception", 4.8)
movie1.display_rating()
# Out:
# Movie: Inception
# Rating: 4.8/5

# %%
# PROBLEM 6: Delivery Address Manager
class Delivery:
    def __init__(self, customer_name, address):
        self.customer_name = customer_name
        self.address = address

    def display_details(self):
        print("Delivery Details")
        print(f"Customer: {self.customer_name}")
        print(f"Address: {self.address}")

# Test Data
delivery1 = Delivery("Suman", "Hyderabad")
delivery1.display_details()
# Out:
# Delivery Details
# Customer: Suman
# Address: Hyderabad
